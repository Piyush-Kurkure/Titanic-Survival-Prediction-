# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import train and test data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
dataset = pd.concat([train,test],ignore_index=True) #ingnoreindex:  do not use the index values along the concatenation axis. The resulting axis will be labeled 0, …, n - 1.
PassengerId = test['PassengerId'] #Retrieve Passenger ID from test set, used for submission

# %%
dataset = dataset.fillna(np.nan) #Check missing values

# %%
dataset.isnull().sum() # check null values
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.dtypes # check datatypes of each column
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.describe() #Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset's distribution
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### SEX Feature
# female has higher survival rate than male

# %%
sns.barplot(x="Sex", y="Survived", data=train, palette='Set3')
print("Percentage of females that could survive: %.2f" %(train['Survived'][train['Sex'] == 'female'].value_counts(normalize = True)[1]*100))
print("Percentage of females that could survive: %.2f" %(train['Survived'][train['Sex'] == 'male'].value_counts(normalize = True)[1]*100))
# Out:
# Percentage of females that could survive: 74.20
# Percentage of females that could survive: 18.89

# %% [markdown]
# ### Pclass Feature
# The higher the class is, the high probability survive

# %%
sns.barplot(x='Pclass', y='Survived', data=train, palette='Set3')
print("Percentage of Pclass = 1, survived probability: %.2f" %(train['Survived'][train['Pclass']==1].value_counts(normalize = True)[1]*100))
print("Percentage of Pclass = 2, survived probability: %.2f" %(train['Survived'][train['Pclass']==2].value_counts(normalize = True)[1]*100))
print("Percentage of Pclass = 3, survived probability: %.2f" %(train['Survived'][train['Pclass']==3].value_counts(normalize = True)[1]*100))
# Out:
# Percentage of Pclass = 1, survived probability: 62.96
# Percentage of Pclass = 2, survived probability: 47.28
# Percentage of Pclass = 3, survived probability: 24.24

# %% [markdown]
# ### SibSp Feature
# With a suitable number of siblings and spouse, he/she will have a high survival rate.

# %%
sns.barplot(x="SibSp", y="Survived", data=train, palette='Set3')

# %% [markdown]
# Like this we can do for all the features

# %% [markdown]
# ### Fill the missing values

# %% [markdown]
# Age feature

# %%
age = dataset[['Age','Pclass','Sex']]
age = pd.get_dummies(age) # Converts sex into sex_male and sex_female
#age

# %%
known_age = age[age.Age.notnull()].as_matrix() # all Age having valid values & as_matrix to represent it in matrix form
null_age = age[age.Age.isnull()].as_matrix()
#known_age
#null_age

# %%
x = known_age[:,1:]
y = known_age[:,0]
#x
#y

# %%
rf = RandomForestRegressor(n_jobs=-1)
rf.fit(x,y)
predictedAge = rf.predict(null_age[:,1:])
#dataset.loc[(dataset.Age.isnull()),'Age'] = predictedAge

# %% [markdown]
# Embarked Feature

# %%
dataset[dataset['Embarked'].isnull()]
# Out:
#       Age Cabin Embarked  Fare                                       Name  \
# 61   38.0   B28      NaN  80.0                        Icard, Miss. Amelie
# 829  62.0   B28      NaN  80.0  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived  Ticket
# 61       0           62       1  female      0       1.0  113572
# 829      0          830       1  female      0       1.0  113572

# %%
C = dataset[(dataset['Embarked']=='C') & (dataset['Pclass']==1)]['Fare'].median()
S = dataset[(dataset['Embarked']=='S') & (dataset['Pclass']==1)]['Fare'].median()
S = dataset[(dataset['Embarked']=='Q') & (dataset['Pclass']==1)]['Fare'].median()
#print(C)
#print(S)
#print(Q)
dataset['Embarked'] = dataset['Embarked'].fillna('C')
#dataset['Embarked']

# %% [markdown]
# Fare Feature

# %%
dataset[dataset['Fare'].isnull()]
# Out:
#        Age Cabin Embarked  Fare                Name  Parch  PassengerId  \
# 1043  60.5   NaN        S   NaN  Storey, Mr. Thomas      0         1044
#
#       Pclass   Sex  SibSp  Survived Ticket
# 1043       3  male      0       NaN   3701

# %%
fare = dataset[(dataset['Embarked']=="S") & (dataset['Pclass']==3)].Fare.median()
dataset['Fare']=dataset['Fare'].fillna(fare)

# %% [markdown]
# Retrieve surname of passenger, classify surnames into same groups

# %%
dataset['Surname'] = dataset['Name'].apply(lambda x:x.split(',')[0].strip()) #Get surnames of each name
#dataset['Surname']
Surname_Count = dict(dataset['Surname'].value_counts()) #Count of each type of surname
#Surname_Count
dataset['FamilyGroup'] = dataset['Surname'].apply(lambda x:Surname_Count[x])
#dataset['FamilyGroup']

# %% [markdown]
# Retrieve the no. of female, child and male from the goups that have more than one person

# %%
Female_Child_Group=dataset.loc[(dataset['FamilyGroup']>=2) & ((dataset['Age']<=12) | (dataset['Sex']=='female'))]
Male_Adult_Group=dataset.loc[(dataset['FamilyGroup']>=2) & (dataset['Age']>12) & (dataset['Sex']=='male')]
Female_Child_Group
# Out:
#         Age        Cabin Embarked      Fare  \
# 1     38.00          C85        C   71.2833
# 3     35.00         C123        S   53.1000
# 7      2.00          NaN        S   21.0750
# 8     27.00          NaN        S   11.1333
# 9     14.00          NaN        C   30.0708
# 10     4.00           G6        S   16.7000
# 11    58.00         C103        S   26.5500
# 16     2.00          NaN        Q   29.1250
# 18    31.00          NaN        S   18.0000
# 22    15.00          NaN        Q    8.0292
# 24     8.00          NaN        S   21.0750
# 25    38.00          NaN        S   31.3875
# 31      NaN          B78        C  146.5208
# 38    18.00          NaN        S   18.0000
# 39    14.00          NaN        C   11.2417
# 41    27.00          NaN        S   21.0000
# 43     3.00          NaN        C   41.5792
# 49    18.00          NaN        S   17.8000
# 50     7.00          NaN        S   39.6875
# 52    49.00          D33        C   76.7292
# 53    29.00          NaN        S   26.0000
# 58     5.00          NaN        S   27.7500
# 59    11.00          NaN        S   46.9000
# 63     4.00          NaN        S   27.9000
# 68    17.00          NaN        S    7.9250
# 71    16.00          NaN        S   46.9000
# 78     0.83          NaN        S   29.0000
# 85    33.00          NaN        S   15.8500
# 88    23.00  C23 C25 C27        S  263.0000
# 98    34.00          NaN        S   23.0000
# ...     ...          ...      ...       ...
# 1205  55.00          C32        C  135.6333
# 1217  12.00           F4        S   39.0000
# 1221  48.00          NaN        S   36.7500
# 1224  19.00          NaN        C   15.7417
# 1234  58.00  B51 B53 B55        C  512.3292
# 1236  16.00          NaN        S    7.6500
# 1241  45.00      D10 D12        C   63.3583
# 1245   0.17          NaN        S   20.5750
# 1247  59.00         C101        S   51.4792
# 1250  30.00          NaN        S   15.5500
# 1252  24.00          NaN        C   37.0042
# 1253  31.00          NaN        S   21.0000
# 1255  25.00          E50        C   55.4417
# 1256    NaN          NaN        S   69.5500
# 1259  45.00          NaN        C   59.4000
# 1265  54.00          A34        S   81.8583
# 1266  45.00          NaN        C  262.3750
# 1267  22.00          NaN        S    8.6625
# 1270   5.00          NaN        S   31.3875
# 1273    NaN          NaN        S   14.5000
# 1274  19.00          NaN        S   16.1000
# 1276  24.00          NaN        S   65.0000
# 1280   6.00          NaN        S   21.0750
# 1282  51.00          D28        S   39.4000
# 1286  18.00          C31        S   60.0000
# 1288  48.00          B41        C   79.2000
# 1291  30.00           C7        S  164.8667
# 1293  22.00          NaN        C   59.4000
# 1300   3.00          NaN        S   13.7750
# 1302  37.00          C78        Q   90.0000
#
#                                                    Name  Parch  PassengerId  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 7                        Palsson, Master. Gosta Leonard      1            8
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                   Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                      Sandstrom, Miss. Marguerite Rut      1           11
# 11                             Bonnell, Miss. Elizabeth      0           12
# 16                                 Rice, Master. Eugene      1           17
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 22                          McGowan, Miss. Anna "Annie"      0           23
# 24                        Palsson, Miss. Torborg Danira      1           25
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 31       Spencer, Mrs. William Augustus (Marie Eugenie)      0           32
# 38                   Vander Planke, Miss. Augusta Maria      0           39
# 39                          Nicola-Yarred, Miss. Jamila      0           40
# 41    Turpin, Mrs. William John Robert (Dorothy Ann ...      0           42
# 43             Laroche, Miss. Simonne Marie Anne Andree      2           44
# 49        Arnold-Franchi, Mrs. Josef (Josefine Franchi)      0           50
# 50                           Panula, Master. Juha Niilo      1           51
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)      0           53
# 53    Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...      0           54
# 58                         West, Miss. Constance Mirium      2           59
# 59                   Goodwin, Master. William Frederick      2           60
# 63                                Skoog, Master. Harald      2           64
# 68                      Andersson, Miss. Erna Alexandra      2           69
# 71                           Goodwin, Miss. Lillian Amy      2           72
# 78                        Caldwell, Master. Alden Gates      2           79
# 85    Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...      0           86
# 88                           Fortune, Miss. Mabel Helen      2           89
# 98                 Doling, Mrs. John T (Ada Julia Bone)      1           99
# ...                                                 ...    ...          ...
# 1205              White, Mrs. John Stuart (Ella Holmes)      0         1206
# 1217                       Becker, Miss. Ruth Elizabeth      1         1218
# 1221  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...      2         1222
# 1224              Nakid, Mrs. Said (Waika Mary" Mowad)"      1         1225
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...      1         1235
# 1236                        Abelseth, Miss. Karen Marie      0         1237
# 1241       Greenfield, Mrs. Leo David (Blanche Strouse)      1         1242
# 1245            Dean, Miss. Elizabeth Gladys Millvina""      2         1246
# 1247     Brown, Mrs. John Murray (Caroline Lane Lamson)      0         1248
# 1250  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...      0         1251
# 1252            Mallet, Mrs. Albert (Antoinette Magnin)      1         1253
# 1253       Ware, Mrs. John James (Florence Louise Long)      0         1254
# 1255       Harder, Mrs. George Achilles (Dorothy Annan)      0         1256
# 1256                     Sage, Mrs. John (Annie Bullen)      9         1257
# 1259            Gibson, Mrs. Leonard (Pauline C Boeson)      1         1260
# 1265              Dodge, Mrs. Washington (Ruth Vidaver)      1         1266
# 1266                           Bowen, Miss. Grace Scott      0         1267
# 1267                                  Kink, Miss. Maria      0         1268
# 1270                        Asplund, Master. Carl Edgar      2         1271
# 1273                         Risien, Mrs. Samuel (Emma)      0         1274
# 1274                McNamee, Mrs. Neal (Eileen O'Leary)      0         1275
# 1276                                 Herman, Miss. Kate      2         1277
# 1280                        Palsson, Master. Paul Folke      1         1281
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 1291                            Bonnell, Miss. Caroline      0         1292
# 1293                     Gibson, Miss. Dorothy Winifred      1         1294
# 1300                          Peacock, Miss. Treasteall      1         1301
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
#
#       Pclass     Sex  SibSp  Survived              Ticket           Surname  \
# 1          1  female      1       1.0            PC 17599           Cumings
# 3          1  female      1       1.0              113803          Futrelle
# 7          3    male      3       0.0              349909           Palsson
# 8          3  female      0       1.0              347742           Johnson
# 9          2  female      1       1.0              237736            Nasser
# 10         3  female      1       1.0             PP 9549         Sandstrom
# 11         1  female      0       1.0              113783           Bonnell
# 16         3    male      4       0.0              382652              Rice
# 18         3  female      1       0.0              345763     Vander Planke
# 22         3  female      0       1.0              330923           McGowan
# 24         3  female      3       0.0              349909           Palsson
# 25         3  female      1       1.0              347077           Asplund
# 31         1  female      1       1.0            PC 17569           Spencer
# 38         3  female      2       0.0              345764     Vander Planke
# 39         3  female      1       1.0                2651     Nicola-Yarred
# 41         2  female      1       0.0               11668            Turpin
# 43         2  female      1       1.0       SC/Paris 2123           Laroche
# 49         3  female      1       0.0              349237    Arnold-Franchi
# 50         3    male      4       0.0             3101295            Panula
# 52         1  female      1       1.0            PC 17572            Harper
# 53         2  female      1       1.0                2926        Faunthorpe
# 58         2  female      1       1.0          C.A. 34651              West
# 59         3    male      5       0.0             CA 2144           Goodwin
# 63         3    male      3       0.0              347088             Skoog
# 68         3  female      4       1.0             3101281         Andersson
# 71         3  female      5       0.0             CA 2144           Goodwin
# 78         2    male      0       1.0              248738          Caldwell
# 85         3  female      3       1.0             3101278         Backstrom
# 88         1  female      3       1.0               19950           Fortune
# 98         2  female      0       1.0              231919            Doling
# ...      ...     ...    ...       ...                 ...               ...
# 1205       1  female      0       NaN            PC 17760             White
# 1217       2  female      2       NaN              230136            Becker
# 1221       2  female      0       NaN          C.A. 33112            Davies
# 1224       3  female      1       NaN                2653             Nakid
# 1234       1  female      0       NaN            PC 17755           Cardeza
# 1236       3  female      0       NaN              348125          Abelseth
# 1241       1  female      0       NaN            PC 17759        Greenfield
# 1245       3  female      1       NaN           C.A. 2315              Dean
# 1247       1  female      2       NaN               11769             Brown
# 1250       3  female      1       NaN              349910           Lindell
# 1252       2  female      1       NaN     S.C./PARIS 2079            Mallet
# 1253       2  female      0       NaN            CA 31352              Ware
# 1255       1  female      1       NaN               11765            Harder
# 1256       3  female      1       NaN            CA. 2343              Sage
# 1259       1  female      0       NaN              112378            Gibson
# 1265       1  female      1       NaN               33638             Dodge
# 1266       1  female      0       NaN            PC 17608             Bowen
# 1267       3  female      2       NaN              315152              Kink
# 1270       3    male      4       NaN              347077           Asplund
# 1273       3  female      0       NaN              364498            Risien
# 1274       3  female      1       NaN              376566           McNamee
# 1276       2  female      1       NaN              220845            Herman
# 1280       3    male      3       NaN              349909           Palsson
# 1282       1  female      0       NaN            PC 17592             Lines
# 1286       1  female      1       NaN               13695             Smith
# 1288       1  female      1       NaN               13567  Frolicher-Stehli
# 1291       1  female      0       NaN               36928           Bonnell
# 1293       1  female      0       NaN              112378            Gibson
# 1300       3  female      1       NaN  SOTON/O.Q. 3101315           Peacock
# 1302       1  female      1       NaN               19928           Minahan
#
#       FamilyGroup
# 1               2
# 3               2
# 7               5
# 8               6
# 9               2
# 10              3
# 11              2
# 16              6
# 18              4
# 22              2
# 24              5
# 25              8
# 31              2
# 38              4
# 39              2
# 41              2
# 43              4
# 49              2
# 50              6
# 52              4
# 53              2
# 58              4
# 59              8
# 63              6
# 68             11
# 71              8
# 78              3
# 85              2
# 88              6
# 98              2
# ...           ...
# 1205            3
# 1217            4
# 1221            7
# 1224            3
# 1234            2
# 1236            2
# 1241            2
# 1245            4
# 1247            6
# 1250            2
# 1252            3
# 1253            4
# 1255            2
# 1256           11
# 1259            2
# 1265            3
# 1266            2
# 1267            2
# 1270            8
# 1273            2
# 1274            2
# 1276            4
# 1280            5
# 1282            2
# 1286            6
# 1288            2
# 1291            2
# 1293            2
# 1300            3
# 1302            3
#
# [350 rows x 14 columns]

# %% [markdown]
# women and children have high survival rate, while men have lower survival rate.
# We set a dead group that women and children group have 0 survival rate. And set survived group for the men's group whose survival rate is 1.

# %%
Female_Child_Group=Female_Child_Group.groupby('Surname')['Survived'].mean()
Dead_List=set(Female_Child_Group[Female_Child_Group.apply(lambda x:x==0)].index)
#print(Dead_List)
Male_Adult_List=Male_Adult_Group.groupby('Surname')['Survived'].mean()
Survived_List=set(Male_Adult_List[Male_Adult_List.apply(lambda x:x==1)].index)
#print(Survived_List)

# %% [markdown]
# In order to classify the samples in these two outliers groups, modigy the Age, Title and Sex of the samples in these two groups.

# %%
train=dataset.loc[dataset['Survived'].notnull()]

# %%
test=dataset.loc[dataset['Survived'].isnull()]

# %%
test.loc[(test['Surname'].apply(lambda x:x in Dead_List)),'Sex'] = 'male'
test.loc[(test['Surname'].apply(lambda x:x in Dead_List)),'Age'] = 60
test.loc[(test['Surname'].apply(lambda x:x in Dead_List)),'Title'] = 'Mr'
test.loc[(test['Surname'].apply(lambda x:x in Survived_List)),'Sex'] = 'female'
test.loc[(test['Surname'].apply(lambda x:x in Survived_List)),'Age'] = 5
test.loc[(test['Surname'].apply(lambda x:x in Survived_List)),'Title'] = 'Miss'

test
# Out:
#        Age            Cabin Embarked      Fare  \
# 891   34.5              NaN        Q    7.8292
# 892   47.0              NaN        S    7.0000
# 893   62.0              NaN        Q    9.6875
# 894   27.0              NaN        S    8.6625
# 895   22.0              NaN        S   12.2875
# 896   14.0              NaN        S    9.2250
# 897   30.0              NaN        Q    7.6292
# 898   26.0              NaN        S   29.0000
# 899   18.0              NaN        C    7.2292
# 900   21.0              NaN        S   24.1500
# 901    NaN              NaN        S    7.8958
# 902   46.0              NaN        S   26.0000
# 903   23.0              B45        S   82.2667
# 904   63.0              NaN        S   26.0000
# 905   47.0              E31        S   61.1750
# 906   24.0              NaN        C   27.7208
# 907   35.0              NaN        Q   12.3500
# 908   21.0              NaN        C    7.2250
# 909   60.0              NaN        S    7.9250
# 910   45.0              NaN        C    7.2250
# 911   55.0              NaN        C   59.4000
# 912    9.0              NaN        S    3.1708
# 913    NaN              NaN        S   31.6833
# 914   21.0              NaN        C   61.3792
# 915   48.0  B57 B59 B63 B66        C  262.3750
# 916   60.0              NaN        S   14.5000
# 917   22.0              B36        C   61.9792
# 918   22.5              NaN        C    7.2250
# 919   41.0              A21        S   30.5000
# 920    NaN              NaN        C   21.6792
# ...    ...              ...      ...       ...
# 1279  60.0              NaN        Q    7.7500
# 1280  60.0              NaN        S   21.0750
# 1281  23.0              B24        S   93.5000
# 1282  51.0              D28        S   39.4000
# 1283  13.0              NaN        S   20.2500
# 1284  47.0              NaN        S   10.5000
# 1285  29.0              NaN        S   22.0250
# 1286  18.0              C31        S   60.0000
# 1287  24.0              NaN        Q    7.2500
# 1288   5.0              B41        C   79.2000
# 1289  22.0              NaN        S    7.7750
# 1290  31.0              NaN        Q    7.7333
# 1291  30.0               C7        S  164.8667
# 1292  38.0              NaN        S   21.0000
# 1293  22.0              NaN        C   59.4000
# 1294  17.0              NaN        S   47.1000
# 1295   5.0              D40        C   27.7208
# 1296  20.0              D38        C   13.8625
# 1297  23.0              NaN        S   10.5000
# 1298  50.0              C80        C  211.5000
# 1299   NaN              NaN        Q    7.7208
# 1300   3.0              NaN        S   13.7750
# 1301   NaN              NaN        Q    7.7500
# 1302  37.0              C78        Q   90.0000
# 1303  28.0              NaN        S    7.7750
# 1304   NaN              NaN        S    8.0500
# 1305  39.0             C105        C  108.9000
# 1306  38.5              NaN        S    7.2500
# 1307   NaN              NaN        S    8.0500
# 1308   NaN              NaN        C   22.3583
#
#                                                    Name  Parch  PassengerId  \
# 891                                    Kelly, Mr. James      0          892
# 892                    Wilkes, Mrs. James (Ellen Needs)      0          893
# 893                           Myles, Mr. Thomas Francis      0          894
# 894                                    Wirz, Mr. Albert      0          895
# 895        Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1          896
# 896                          Svensson, Mr. Johan Cervin      0          897
# 897                                Connolly, Miss. Kate      0          898
# 898                        Caldwell, Mr. Albert Francis      1          899
# 899           Abrahim, Mrs. Joseph (Sophie Halaut Easu)      0          900
# 900                             Davies, Mr. John Samuel      0          901
# 901                                    Ilieff, Mr. Ylio      0          902
# 902                          Jones, Mr. Charles Cresson      0          903
# 903       Snyder, Mrs. John Pillsbury (Nelle Stevenson)      0          904
# 904                                Howard, Mr. Benjamin      0          905
# 905   Chaffee, Mrs. Herbert Fuller (Carrie Constance...      0          906
# 906       del Carlo, Mrs. Sebastiano (Argenia Genovesi)      0          907
# 907                                   Keane, Mr. Daniel      0          908
# 908                                   Assaf, Mr. Gerios      0          909
# 909                        Ilmakangas, Miss. Ida Livija      0          910
# 910               Assaf Khalil, Mrs. Mariana (Miriam")"      0          911
# 911                              Rothschild, Mr. Martin      0          912
# 912                           Olsen, Master. Artur Karl      1          913
# 913                Flegenheim, Mrs. Alfred (Antoinette)      0          914
# 914                     Williams, Mr. Richard Norris II      1          915
# 915     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)      3          916
# 916                             Robins, Mr. Alexander A      0          917
# 917                        Ostby, Miss. Helene Ragnhild      1          918
# 918                                   Daher, Mr. Shedid      0          919
# 919                             Brady, Mr. John Bertram      0          920
# 920                                   Samaan, Mr. Elias      0          921
# ...                                                 ...    ...          ...
# 1279                               Canavan, Mr. Patrick      0         1280
# 1280                        Palsson, Master. Paul Folke      1         1281
# 1281                         Payne, Mr. Vivian Ponsonby      0         1282
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 1283                      Abbott, Master. Eugene Joseph      2         1284
# 1284                               Gilbert, Mr. William      0         1285
# 1285                           Kink-Heilmann, Mr. Anton      1         1286
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 1287                               Colbert, Mr. Patrick      0         1288
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 1289                     Larsson-Rondberg, Mr. Edvard A      0         1290
# 1290                           Conlon, Mr. Thomas Henry      0         1291
# 1291                            Bonnell, Miss. Caroline      0         1292
# 1292                                    Gale, Mr. Harry      0         1293
# 1293                     Gibson, Miss. Dorothy Winifred      1         1294
# 1294                             Carrau, Mr. Jose Pedro      0         1295
# 1295                       Frauenthal, Mr. Isaac Gerald      0         1296
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297
# 1297                          Ware, Mr. William Jeffery      0         1298
# 1298                         Widener, Mr. George Dunton      1         1299
# 1299                    Riordan, Miss. Johanna Hannah""      0         1300
# 1300                          Peacock, Miss. Treasteall      1         1301
# 1301                             Naughton, Miss. Hannah      0         1302
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 1303                     Henriksson, Miss. Jenny Lovisa      0         1304
# 1304                                 Spector, Mr. Woolf      0         1305
# 1305                       Oliva y Ocana, Dona. Fermina      0         1306
# 1306                       Saether, Mr. Simon Sivertsen      0         1307
# 1307                                Ware, Mr. Frederick      0         1308
# 1308                           Peter, Master. Michael J      1         1309
#
#       Pclass     Sex  SibSp  Survived              Ticket           Surname  \
# 891        3    male      0       NaN              330911             Kelly
# 892        3  female      1       NaN              363272            Wilkes
# 893        2    male      0       NaN              240276             Myles
# 894        3    male      0       NaN              315154              Wirz
# 895        3  female      1       NaN             3101298          Hirvonen
# 896        3    male      0       NaN                7538          Svensson
# 897        3  female      0       NaN              330972          Connolly
# 898        2    male      1       NaN              248738          Caldwell
# 899        3  female      0       NaN                2657           Abrahim
# 900        3    male      2       NaN           A/4 48871            Davies
# 901        3    male      0       NaN              349220            Ilieff
# 902        1    male      0       NaN                 694             Jones
# 903        1  female      1       NaN               21228            Snyder
# 904        2    male      1       NaN               24065            Howard
# 905        1  female      1       NaN         W.E.P. 5734           Chaffee
# 906        2  female      1       NaN       SC/PARIS 2167         del Carlo
# 907        2    male      0       NaN              233734             Keane
# 908        3    male      0       NaN                2692             Assaf
# 909        3    male      1       NaN    STON/O2. 3101270        Ilmakangas
# 910        3  female      0       NaN                2696      Assaf Khalil
# 911        1    male      1       NaN            PC 17603        Rothschild
# 912        3    male      0       NaN             C 17368             Olsen
# 913        1  female      0       NaN            PC 17598        Flegenheim
# 914        1    male      0       NaN            PC 17597          Williams
# 915        1  female      1       NaN            PC 17608           Ryerson
# 916        3    male      1       NaN           A/5. 3337            Robins
# 917        1  female      0       NaN              113509             Ostby
# 918        3    male      0       NaN                2698             Daher
# 919        1    male      0       NaN              113054             Brady
# 920        3    male      2       NaN                2662            Samaan
# ...      ...     ...    ...       ...                 ...               ...
# 1279       3    male      0       NaN              364858           Canavan
# 1280       3    male      3       NaN              349909           Palsson
# 1281       1    male      0       NaN               12749             Payne
# 1282       1  female      0       NaN            PC 17592             Lines
# 1283       3    male      0       NaN           C.A. 2673            Abbott
# 1284       2    male      0       NaN          C.A. 30769           Gilbert
# 1285       3    male      3       NaN              315153     Kink-Heilmann
# 1286       1  female      1       NaN               13695             Smith
# 1287       3    male      0       NaN              371109           Colbert
# 1288       1  female      1       NaN               13567  Frolicher-Stehli
# 1289       3    male      0       NaN              347065  Larsson-Rondberg
# 1290       3    male      0       NaN               21332            Conlon
# 1291       1  female      0       NaN               36928           Bonnell
# 1292       2    male      1       NaN               28664              Gale
# 1293       1  female      0       NaN              112378            Gibson
# 1294       1    male      0       NaN              113059            Carrau
# 1295       1  female      1       NaN               17765        Frauenthal
# 1296       2    male      0       NaN       SC/PARIS 2166           Nourney
# 1297       2    male      1       NaN               28666              Ware
# 1298       1    male      1       NaN              113503           Widener
# 1299       3  female      0       NaN              334915           Riordan
# 1300       3  female      1       NaN  SOTON/O.Q. 3101315           Peacock
# 1301       3  female      0       NaN              365237          Naughton
# 1302       1  female      1       NaN               19928           Minahan
# 1303       3  female      0       NaN              347086        Henriksson
# 1304       3    male      0       NaN           A.5. 3236           Spector
# 1305       1  female      0       NaN            PC 17758     Oliva y Ocana
# 1306       3    male      0       NaN  SOTON/O.Q. 3101262           Saether
# 1307       3    male      0       NaN              359309              Ware
# 1308       3    male      1       NaN                2668             Peter
#
#       FamilyGroup Title
# 891             5   NaN
# 892             1   NaN
# 893             1   NaN
# 894             1   NaN
# 895             2   NaN
# 896             3   NaN
# 897             2   NaN
# 898             3   NaN
# 899             1   NaN
# 900             7   NaN
# 901             1   NaN
# 902             1   NaN
# 903             2   NaN
# 904             3   NaN
# 905             2   NaN
# 906             2   NaN
# 907             3   NaN
# 908             1   NaN
# 909             2    Mr
# 910             1   NaN
# 911             2   NaN
# 912             4   NaN
# 913             1   NaN
# 914             5   NaN
# 915             5   NaN
# 916             2    Mr
# 917             2   NaN
# 918             1   NaN
# 919             1   NaN
# 920             3   NaN
# ...           ...   ...
# 1279            2    Mr
# 1280            5    Mr
# 1281            1   NaN
# 1282            2   NaN
# 1283            3   NaN
# 1284            1   NaN
# 1285            3   NaN
# 1286            6   NaN
# 1287            1   NaN
# 1288            2  Miss
# 1289            1   NaN
# 1290            1   NaN
# 1291            2   NaN
# 1292            2   NaN
# 1293            2   NaN
# 1294            2   NaN
# 1295            3  Miss
# 1296            1   NaN
# 1297            4   NaN
# 1298            3   NaN
# 1299            1   NaN
# 1300            3   NaN
# 1301            1   NaN
# 1302            3   NaN
# 1303            1   NaN
# 1304            1   NaN
# 1305            1   NaN
# 1306            1   NaN
# 1307            4   NaN
# 1308            3   NaN
#
# [418 rows x 15 columns]

# %% [markdown]
# Select Survived, Pclass, Sex, Age, Fare, Embarked, Title, FamilyLabel, Deck and TicketGroup as features and transfer the features into numerial values.

# %%
dataset = pd.concat([train, test])
dataset=dataset[['Survived','Pclass','Sex','Age','Fare','Embarked','Title']]
dataset=pd.get_dummies(dataset)

# %%
trainset=dataset[dataset['Survived'].notnull()]
testset=dataset[dataset['Survived'].isnull()].drop('Survived',axis=1)
X = trainset.as_matrix()[:,1:]
Y = trainset.as_matrix()[:,0]

# %% [markdown]
# ### Model Training

# %% [markdown]
# Use grid search to find the best parameter of random forest classifier.

# %% [markdown]
# pipe=Pipeline([('select',SelectKBest(k=20)),
#                ('classify', RandomForestClassifier(random_state = 10, max_features = 'sqrt'))])
#
# param_test = {'classify__n_estimators':list(range(20,50,2)),
#               'classify__max_depth':list(range(3,60,3))}
# gsearch = GridSearchCV(estimator = pipe, param_grid = param_test, scoring='accuracy', cv=10)
# gsearch.fit(X,Y)
# print(gsearch.best_params_, gsearch.best_score_)

# %% [markdown]
# select = SelectKBest(k = 20)
# clf = RandomForestClassifier(random_state = 10, warm_start = True,
#                                   n_estimators = 26,
#                                   max_depth = 6,
#                                   max_features = 'sqrt')
# pipeline = make_pipeline(select, clf)
# pipeline.fit(X, Y)

# %% [markdown]
# ### Cross Validation

# %% [markdown]
# cv_score = model_selection.cross_val_score(pipeline, X, Y, cv= 10)
# print("CV Score : Mean - %.7g | Std - %.7g " % (np.mean(cv_score), np.std(cv_score)))

# %% [markdown]
# ### Submission

# %% [markdown]
# predictions = pipeline.predict(testset)
# submission = pd.DataFrame({"PassengerId": PassengerId, "Survived": predictions.astype(np.int32)})
# submission.to_csv("submission.csv", index=False)
